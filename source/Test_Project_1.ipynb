# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# IPython             _xxsubinterpreters  idna                secrets
# Test_Project_1      _xxtestfuzz         imaplib             select
# __future__          _yaml               imghdr              selectors
# __hello__           _zoneinfo           importlib           setuptools
# __phello__          abc                 inspect             shellingham
# _abc                aifc                io                  shelve
# _aix_support        annotated_types     ipaddress           shlex
# _ast                antigravity         ipykernel           shutil
# _asyncio            anyio               ipykernel_launcher  signal
# _bisect             argparse            itertools           site
# _blake2             array               jedi                six
# _bz2                ast                 jinja2              smtplib
# _codecs             asttokens           json                sndhdr
# ...
